# %%
#Crop Prediction
import pandas.plotting as pdplt
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
# import tflearn.data_utils as du
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

# %%
df = pd.read_csv("CPDATA.csv")

print (df['label'].unique())


def encode_target(df, target_column):
    df_mod = df.copy()
    targets = df_mod[target_column].unique()
    map_to_int = {name: n for n, name in enumerate(targets)}
    df_mod["Target"] = df_mod[target_column].replace(map_to_int)
    return df_mod, targets
df2, targets = encode_target(df, "label")


#df.cumsum()
#plt.show()
#plt.figure()
#plt.show()
#df.plot()
# Out:
# ['rice' 'wheat' 'Mung Bean' 'Tea' 'millet' 'maize' 'Lentil' 'Jute'
#  'Coffee' 'Cotton' 'Ground Nut' 'Peas' 'Rubber' 'Sugarcane' 'Tobacco'
#  'Kidney Beans' 'Moth Beans' 'Coconut' 'Black gram' 'Adzuki Beans'
#  'Pigeon Peas' 'Chickpea' 'banana' 'grapes' 'apple' 'mango' 'muskmelon'
#  'orange' 'papaya' 'pomegranate' 'watermelon']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Calculating the correlation matrix
corr = df.corr()
# Generating a heatmap
fig, ax = plt.subplots(figsize=(20,20))   
sns.heatmap(corr, annot=True, linewidths=.5, ax=ax)
# sns.heatmap(corr,xticklabels=corr.columns, yticklabels=corr.columns)

# %%
sns.pairplot(df, hue="label", size=3)
plt.show()
pdplt.andrews_curves(df,"label",ax=None)
plt.show()
plt.figure()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
features = list(df2.columns[:4])
y = df2["Target"]
X = df2[features]
dt = DecisionTreeClassifier(max_depth=32,min_samples_split=20, random_state=99)

dt.fit(X, y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=32, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=20,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=99, splitter='best')

# %%
#If Testing Consists Of One Record

dt_test = pd.read_csv("BOOK1.csv")
final_data = dt_test
type = dt.predict(final_data)


if (type==0):
    print ("Predicted Crop is: Rice")
elif (type==1):
    print ("Predicted Crop is: Wheat")
elif (type==2):
    print ("Predicted Crop is: Mung Bean")
elif (type==3):
    print ("Predicted Crop is: Tea")
elif (type==4):
    print ("Predicted Crop is: Millet")
elif (type==5):
    print ("Predicted Crop is: Maize")
elif (type==6):
    print ("Predicted Crop is: Lentil")
elif (type==7):
    print ("Predicted Crop is: Jute")
elif (type==8):
    print ("Predicted Crop is: Coffee")
elif (type==9):
    print ("Predicted Crop is: Cotton")
elif (type==10):
    print ("Predicted Crop is: Groundnut")
elif (type==11):
    print ("Predicted Crop is: Peas")
elif (type==12):
    print ("Predicted Crop is: Rubber")
elif (type==13):
    print ("Predicted Crop is: Sugarcane")
elif (type==14):
    print ("Predicted Crop is: Tobacco")
elif (type==15):
    print ("Predicted Crop is: Kidney Beans")
elif (type==16):
    print ("Predicted Crop is: Moth Beans")
elif (type==17):
    print ("Predicted Crop is: Coconut")
elif (type==18):
    print ("Predicted Crop is: Black Gram")
elif (type==19):
    print ("Predicted Crop is: Adzuki Beans")
elif (type==20):
    print ("Predicted Crop is: Pigeon Peas")
elif (type==21):
    print ("Predicted Crop is: Chickpea")
elif (type==22):
    print ("Predicted Crop is: Banana")
elif (type==23):
    print ("Predicted Crop is: Grapes")
elif (type==24):
    print ("Predicted Crop is: Apple")
elif (type==25):
    print ("Predicted Crop is: Mango")
elif (type==26):
    print ("Predicted Crop is: Muskmelon")
elif (type==27):
    print ("Predicted Crop is: Orange")
elif (type==28):
    print ("Predicted Crop is: Papaya")
elif (type==29):
    print ("Predicted Crop is: Pomegranate")
else:
    print ("Predicted Crop is: Watermelon")
# Out:
# Predicted Crop is: Rice

# %%
#If Testing Consists Of Multiple Records

dt_test = pd.read_csv("BOOK.csv")
final_data = dt_test
type = dt.predict(final_data)

for i in type:
    
    if (type[i]==0):
        print ("Predicted Crop is: Rice")
    elif (type[i]==1):
        print ("Predicted Crop is: Wheat")
    elif (type[i]==2):
        print ("Predicted Crop is: Mung Bean")
    elif (type[i]==3):
        print ("Predicted Crop is: Tea")
    elif (type[i]==4):
        print ("Predicted Crop is: Millet")
    elif (type[i]==5):
        print ("Predicted Crop is: Maize")
    elif (type[i]==6):
        print ("Predicted Crop is: Lentil")
    elif (type[i]==7):
        print ("Predicted Crop is: Jute")
    elif (type[i]==8):
        print ("Predicted Crop is: Coffee")
    elif (type[i]==9):
        print ("Predicted Crop is: Cotton")
    elif (type[i]==10):
        print ("Predicted Crop is: Groundnut")
    elif (type[i]==11):
        print ("Predicted Crop is: Peas")
    elif (type[i]==12):
        print ("Predicted Crop is: Rubber")
    elif (type[i]==13):
        print ("Predicted Crop is: Sugarcane")
    elif (type[i]==14):
        print ("Predicted Crop is: Tobacco")
    elif (type[i]==15):
        print ("Predicted Crop is: Kidney Beans")
    elif (type[i]==16):
        print ("Predicted Crop is: Moth Beans")
    elif (type[i]==17):
        print ("Predicted Crop is: Coconut")
    elif (type[i]==18):
        print ("Predicted Crop is: Black Gram")
    elif (type[i]==19):
        print ("Predicted Crop is: Adzuki Beans")
    elif (type[i]==20):
        print ("Predicted Crop is: Pigeon Peas")
    elif (type[i]==21):
        print ("Predicted Crop is: Chickpea")
    elif (type[i]==22):
        print ("Predicted Crop is: Banana")
    elif (type[i]==23):
        print ("Predicted Crop is: Grapes")
    elif (type[i]==24):
        print ("Predicted Crop is: Apple")
    elif (type[i]==25):
        print ("Predicted Crop is: Mango")
    elif (type[i]==26):
        print ("Predicted Crop is: Muskmelon")
    elif (type[i]==27):
        print ("Predicted Crop is: Orange")
    elif (type[i]==28):
        print ("Predicted Crop is: Papaya")
    elif (type[i]==29):
        print ("Predicted Crop is: Pomegranate")
    else:
        print ("Predicted Crop is: Watermelon")
    
    i=i+1
# Out:
# Predicted Crop is: Rice
# Predicted Crop is: Wheat
# Predicted Crop is: Mung Bean
# Predicted Crop is: Tea
# Predicted Crop is: Millet
# Predicted Crop is: Maize
# Predicted Crop is: Lentil
# Predicted Crop is: Jute
# Predicted Crop is: Coffee
# Predicted Crop is: Cotton
# Predicted Crop is: Groundnut
# Predicted Crop is: Peas
# Predicted Crop is: Rubber
# Predicted Crop is: Sugarcane
# Predicted Crop is: Tobacco
# Predicted Crop is: Kidney Beans
# Predicted Crop is: Moth Beans
# Predicted Crop is: Coconut
# Predicted Crop is: Black Gram
# Predicted Crop is: Adzuki Beans
# Predicted Crop is: Pigeon Peas
# Predicted Crop is: Chickpea
# Predicted Crop is: Banana
# Predicted Crop is: Grapes
# Predicted Crop is: Apple
# Predicted Crop is: Mango
# Predicted Crop is: Muskmelon
# Predicted Crop is: Orange
# Predicted Crop is: Papaya
# Predicted Crop is: Pomegranate
# Predicted Crop is: Watermelon

# %%
#Decision Tree Visualisation; It Will Be Saved In The Same Directory Itself

features=['temperature', 'humidity','pH','rainfall']
crops=['rice','wheat','mungbean','Tea','millet','maize','lentil','jute','cofee','cotton','ground nut','peas','rubber','sugarcane','tobacco','kidney beans','moth beans','coconut','blackgram','adzuki beans','pigeon peas','chick peas','banana','grapes','apple','mango','muskmelon','orange','papaya','watermelon','pomegranate']


def visualize_tree(tree,feature_names):

    with open("DT.dot", 'w') as f:
        export_graphviz(dt, out_file=f, feature_names=features, class_names=crops)

    command = ["dot", "-Tpng", "DT.dot", "-o", "DT.png"]
    try:
        subprocess.check_call(command)
    except:
        exit("Could not run dot, ie graphviz, to "
             "produce visualization")

visualize_tree(dt, features)
'''
data_clean = AH_data.dropna()
#data_clean.dtypes
#data_clean.describe()
predictors = [['Humidity','Temp','Moisture','LDR']]
targets = data_clean.output
pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, targets, test_size=.4)
'''
'''
classifier = DecisionTreeClassifier()
classifier = classifier.fit(pred_train,tar_train)
predictions = classifier.predict(pred_test)
print predictions
sklearn.metrics.accuracy_score(tar_test, predictions)
'''
# Out:
# '\nclassifier = DecisionTreeClassifier()\nclassifier = classifier.fit(pred_train,tar_train)\npredictions = classifier.predict(pred_test)\nprint predictions\nsklearn.metrics.accuracy_score(tar_test, predictions)\n'
